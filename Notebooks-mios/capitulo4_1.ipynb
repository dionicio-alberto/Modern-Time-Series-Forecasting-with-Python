# %%
# %cd ..
# Out:
# c:\Users\dioni\Documents\GitHub\Modern-Time-Series-Forecasting-with-Python

# %%
import numpy as np
import pandas as pd
import time
import plotly.express as px
import plotly.graph_objects as go
import os
import plotly.io as pio
pio.templates.default = "plotly_white"

from pathlib import Path
from tqdm import tqdm
import warnings
import humanize

#If importing darts is throwing an error, import torch beforehand and then import darts
# import torch
from darts import TimeSeries
from darts.models import ARIMA

from darts.metrics import mase, mse, mae, ope

from src.utils.ts_utils import forecast_bias
from src.utils.general import LogTime
from src.utils import plotting_utils

#%load_ext autoreload
#%autoreload 2

np.random.seed(42)
tqdm.pandas()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# c:\Users\dioni\Documents\GitHub\Modern-Time-Series-Forecasting-with-Python\Notebooks-mios\capitulo4_1.ipynb Celda 2 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#W1sZmlsZQ%3D%3D?line=14'>15</a> #If importing darts is throwing an error, import torch beforehand and then import darts
#      <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#W1sZmlsZQ%3D%3D?line=15'>16</a> # import torch
#      <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#W1sZmlsZQ%3D%3D?line=16'>17</a> from darts import TimeSeries
# ---> <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#W1sZmlsZQ%3D%3D?line=17'>18</a> from darts.models import ARIMA
#      <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#W1sZmlsZQ%3D%3D?line=19'>20</a> from darts.metrics import mase, mse, mae, ope
#      <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#W1sZmlsZQ%3D%3D?line=21'>22</a> from src.utils.ts_utils import forecast_bias
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\darts\models\__init__.py:32
#      29 from darts.models.utils import NotImportedModule
#      31 try:
# ---> 32     from darts.models.forecasting.block_rnn_model import BlockRNNModel
#      33     from darts.models.forecasting.dlinear import DLinearModel
#      34     from darts.models.forecasting.nbeats import NBEATSModel
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\darts\models\forecasting\block_rnn_model.py:12
#       9 import torch.nn as nn
#      11 from darts.logging import get_logger, raise_if_not
# ---> 12 from darts.models.forecasting.pl_forecasting_module import (
#      13     PLPastCovariatesModule,
#      14     io_processor,
#      15 )
#      16 from darts.models.forecasting.torch_forecasting_model import PastCovariatesTorchModel
#      18 logger = get_logger(__name__)
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\darts\models\forecasting\pl_forecasting_module.py:8
#       5 from abc import ABC, abstractmethod
#       6 from typing import Any, Dict, Optional, Sequence, Tuple, Union
# ----> 8 import pytorch_lightning as pl
#       9 import torch
#      10 import torch.nn as nn
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\pytorch_lightning\__init__.py:20
#      17 _PACKAGE_ROOT = os.path.dirname(__file__)
#      18 _PROJECT_ROOT = os.path.dirname(_PACKAGE_ROOT)
# ---> 20 from pytorch_lightning.callbacks import Callback  # noqa: E402
#      21 from pytorch_lightning.core import LightningDataModule, LightningModule  # noqa: E402
#      22 from pytorch_lightning.trainer import Trainer  # noqa: E402
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\pytorch_lightning\callbacks\__init__.py:26
#      24 from pytorch_lightning.callbacks.prediction_writer import BasePredictionWriter
#      25 from pytorch_lightning.callbacks.progress import ProgressBar, ProgressBarBase, RichProgressBar, TQDMProgressBar
# ---> 26 from pytorch_lightning.callbacks.pruning import ModelPruning
#      27 from pytorch_lightning.callbacks.quantization import QuantizationAwareTraining
#      28 from pytorch_lightning.callbacks.rich_model_summary import RichModelSummary
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\pytorch_lightning\callbacks\pruning.py:31
#      29 import pytorch_lightning as pl
#      30 from pytorch_lightning.callbacks.base import Callback
# ---> 31 from pytorch_lightning.core.lightning import LightningModule
#      32 from pytorch_lightning.utilities.apply_func import apply_to_collection
#      33 from pytorch_lightning.utilities.distributed import rank_zero_debug, rank_zero_only
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\pytorch_lightning\core\__init__.py:15
#       1 # Copyright The PyTorch Lightning team.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 15 from pytorch_lightning.core.datamodule import LightningDataModule
#      16 from pytorch_lightning.core.lightning import LightningModule
#      18 __all__ = ["LightningDataModule", "LightningModule"]
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\pytorch_lightning\core\datamodule.py:23
#      20 from torch.utils.data import DataLoader, Dataset, IterableDataset
#      22 from pytorch_lightning.core.hooks import CheckpointHooks, DataHooks
# ---> 23 from pytorch_lightning.core.mixins import HyperparametersMixin
#      24 from pytorch_lightning.utilities import rank_zero_deprecation
#      25 from pytorch_lightning.utilities.argparse import add_argparse_args, from_argparse_args, get_init_arguments_and_types
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\pytorch_lightning\core\mixins\__init__.py:16
#       1 # Copyright The PyTorch Lightning team.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from pytorch_lightning.core.mixins.device_dtype_mixin import DeviceDtypeModuleMixin  # noqa: F401
# ---> 16 from pytorch_lightning.core.mixins.hparams_mixin import HyperparametersMixin
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\pytorch_lightning\core\mixins\hparams_mixin.py:20
#      17 from argparse import Namespace
#      18 from typing import MutableMapping, Optional, Sequence, Union
# ---> 20 from pytorch_lightning.core.saving import ALLOWED_CONFIG_TYPES, PRIMITIVE_TYPES
#      21 from pytorch_lightning.utilities import AttributeDict
#      22 from pytorch_lightning.utilities.parsing import save_hyperparameters
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\pytorch_lightning\core\saving.py:41
#      38 ALLOWED_CONFIG_TYPES = (AttributeDict, MutableMapping, Namespace)
#      40 if _OMEGACONF_AVAILABLE:
# ---> 41     from omegaconf import OmegaConf
#      42     from omegaconf.dictconfig import DictConfig
#      43     from omegaconf.errors import UnsupportedValueType, ValidationError
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\omegaconf\__init__.py:1
# ----> 1 from .base import Container, DictKeyType, Node, SCMode
#       2 from .dictconfig import DictConfig
#       3 from .errors import (
#       4     KeyValidationError,
#       5     MissingMandatoryValue,
#    (...)
#       8     ValidationError,
#       9 )
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\omegaconf\base.py:11
#       7 from typing import Any, Dict, Iterator, List, Optional, Set, Tuple, Type, Union
#       9 from antlr4 import ParserRuleContext
# ---> 11 from ._utils import (
#      12     _DEFAULT_MARKER_,
#      13     ValueKind,
#      14     _get_value,
#      15     _is_missing_value,
#      16     format_and_raise,
#      17     get_value_kind,
#      18     split_key,
#      19 )
#      20 from .errors import (
#      21     ConfigKeyError,
#      22     ConfigTypeError,
#    (...)
#      29     ValidationError,
#      30 )
#      31 from .grammar.gen.OmegaConfGrammarParser import OmegaConfGrammarParser
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\omegaconf\_utils.py:32
#      22 import yaml
#      24 from .errors import (
#      25     ConfigIndexError,
#      26     ConfigTypeError,
#    (...)
#      30     ValidationError,
#      31 )
# ---> 32 from .grammar_parser import SIMPLE_INTERPOLATION_PATTERN, parse
#      34 try:
#      35     import dataclasses
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\omegaconf\grammar_parser.py:12
#       8 from .errors import GrammarParseError
#      10 # Import from visitor in order to check the presence of generated grammar files
#      11 # files in a single place.
# ---> 12 from .grammar_visitor import (  # type: ignore
#      13     OmegaConfGrammarLexer,
#      14     OmegaConfGrammarParser,
#      15 )
#      17 # Used to cache grammar objects to avoid re-creating them on each call to `parse()`.
#      18 # We use a per-thread cache to make it thread-safe.
#      19 _grammar_cache = threading.local()
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\omegaconf\grammar_visitor.py:25
#      22     from .base import Node  # noqa F401
#      24 try:
# ---> 25     from omegaconf.grammar.gen.OmegaConfGrammarLexer import OmegaConfGrammarLexer
#      26     from omegaconf.grammar.gen.OmegaConfGrammarParser import OmegaConfGrammarParser
#      27     from omegaconf.grammar.gen.OmegaConfGrammarParserVisitor import (
#      28         OmegaConfGrammarParserVisitor,
#      29     )
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\omegaconf\grammar\gen\OmegaConfGrammarLexer.py:254
#     250         buf.write("\3\2\t\f\2\t\r\2\t\24\2\t\4\2\t\25\2\t\32\2\t\33\2")
#     251         return buf.getvalue()
# --> 254 class OmegaConfGrammarLexer(Lexer):
#     256     atn = ATNDeserializer().deserialize(serializedATN())
#     258     decisionsToDFA = [ DFA(ds, i) for i, ds in enumerate(atn.decisionToState) ]
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\omegaconf\grammar\gen\OmegaConfGrammarLexer.py:256, in OmegaConfGrammarLexer()
#     254 class OmegaConfGrammarLexer(Lexer):
# --> 256     atn = ATNDeserializer().deserialize(serializedATN())
#     258     decisionsToDFA = [ DFA(ds, i) for i, ds in enumerate(atn.decisionToState) ]
#     260     VALUE_MODE = 1
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\antlr4\atn\ATNDeserializer.py:28, in ATNDeserializer.deserialize(self, data)
#      26 self.data = data
#      27 self.pos = 0
# ---> 28 self.checkVersion()
#      29 atn = self.readATN()
#      30 self.readStates(atn)
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\antlr4\atn\ATNDeserializer.py:50, in ATNDeserializer.checkVersion(self)
#      48 version = self.readInt()
#      49 if version != SERIALIZED_VERSION:
# ---> 50     raise Exception("Could not deserialize ATN with version " + str(version) + " (expected " + str(SERIALIZED_VERSION) + ").")
#
# Exception: Could not deserialize ATN with version  (expected 4).

# %%
os.makedirs("imgs/chapter_4", exist_ok=True)
preprocessed = Path("data/london_smart_meters/preprocessed")

# %%
def format_plot(fig, legends = None, xlabel="Time", ylabel="Value", title="", font_size=15):
    if legends:
        names = cycle(legends)
        fig.for_each_trace(lambda t:  t.update(name = next(names)))
    fig.update_layout(
            autosize=False,
            width=900,
            height=500,
            title_text=title,
            title={
            'x':0.5,
            'xanchor': 'center',
            'yanchor': 'top'},
            titlefont={
                "size": 20
            },
            legend_title = None,
            legend=dict(
                font=dict(size=font_size),
                orientation="h",
                yanchor="bottom",
                y=0.98,
                xanchor="right",
                x=1,
            ),
            yaxis=dict(
                title_text=ylabel,
                titlefont=dict(size=font_size),
                tickfont=dict(size=font_size),
            ),
            xaxis=dict(
                title_text=xlabel,
                titlefont=dict(size=font_size),
                tickfont=dict(size=font_size),
            )
        )
    return fig

# %%
#Readin the missing value imputed and train test split data
try:
    train_df = pd.read_parquet(preprocessed/"selected_blocks_train_missing_imputed.parquet")
    val_df = pd.read_parquet(preprocessed/"selected_blocks_val_missing_imputed.parquet")
    test_df = pd.read_parquet(preprocessed/"selected_blocks_test_missing_imputed.parquet")
except FileNotFoundError:
    display(HTML("""
    <div class="alert alert-block alert-warning">
    <b>Warning!</b> File not found. Please make sure you have run 01-Setting up Experiment Harness.ipynb in Chapter04
    </div>
    """))

# %%
len(train_df.LCLid.unique())
# Out:
# 150

# %%
#picking a single time series from the dataset for illustration
freq = train_df.iloc[0]['frequency']
ts_train = train_df.loc[train_df.LCLid=="MAC000193", ["timestamp","energy_consumption"]].set_index("timestamp")
ts_val = val_df.loc[val_df.LCLid=="MAC000193", ["timestamp","energy_consumption"]].set_index("timestamp")
ts_test = test_df.loc[test_df.LCLid=="MAC000193", ["timestamp","energy_consumption"]].set_index("timestamp")

# %% [markdown]
# # Baseline Forecasts

# %%
pred_df = pd.concat([ts_train, ts_val])
metric_record = []

ts_train = TimeSeries.from_series(ts_train)
ts_val = TimeSeries.from_series(ts_val)
ts_test = TimeSeries.from_series(ts_test)

# %%
def eval_model(model, ts_train, ts_test, name=None):
    if name is None:
        name = type(model).__name__
    model.fit(ts_train)
    y_pred = model.predict(len(ts_test))
    return y_pred, {
        "Algorithm": name,
        "MAE": mae(actual_series = ts_test, pred_series = y_pred),
        "MSE": mse(actual_series = ts_test, pred_series = y_pred),
        "MASE": mase(actual_series = ts_test, pred_series = y_pred, insample=ts_train),
        "Forecast Bias": forecast_bias(actual_series = ts_test, pred_series = y_pred)
    }

def format_y_pred(y_pred, name):
    y_pred = y_pred.data_array().to_series()
    y_pred.index = y_pred.index.get_level_values(0)
    y_pred.name = name
    return y_pred

# %%
from itertools import cycle
def plot_forecast(pred_df, forecast_columns, forecast_display_names=None):
    if forecast_display_names is None:
        forecast_display_names = forecast_columns
    else:
        assert len(forecast_columns)==len(forecast_display_names)
    mask = ~pred_df[forecast_columns[0]].isnull()
    # colors = ["rgba("+",".join([str(c) for c in plotting_utils.hex_to_rgb(c)])+",<alpha>)" for c in px.colors.qualitative.Plotly]
    colors = [c.replace("rgb", "rgba").replace(")", ", <alpha>)") for c in px.colors.qualitative.Dark2]
    # colors = [c.replace("rgb", "rgba").replace(")", ", <alpha>)") for c in px.colors.qualitative.Safe]
    act_color = colors[0]
    colors = cycle(colors[1:])
    dash_types = cycle(["dash","dot","dashdot"])
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=pred_df[mask].index, y=pred_df[mask].energy_consumption,
                        mode='lines', line = dict(color=act_color.replace("<alpha>", "0.3")),
                        name='Actual Consumption'))
    for col, display_col in zip(forecast_columns,forecast_display_names):
        fig.add_trace(go.Scatter(x=pred_df[mask].index, y=pred_df.loc[mask, col],
                            mode='lines', line = dict(dash=next(dash_types), color=next(colors).replace("<alpha>", "1")),
                            name=display_col))
    return fig

# %% [markdown]
# # Naive Forecast

# %%
name = "Naive"
naive_model = NaiveSeasonal(K=1)
with LogTime() as timer:
    y_pred, metrics = eval_model(naive_model, ts_train, ts_val, name=name)
metrics['Time Elapsed'] = timer.elapsed
metric_record.append(metrics)
y_pred = format_y_pred(y_pred, "naive_predictions")
pred_df = pred_df.join(y_pred)
# Out:
# Time Elapsed: 0 microseconds

# %%
metric_record
# Out:
# [{'Algorithm': 'Naive',
#   'MAE': 0.3053945,
#   'MSE': 0.249304,
#   'MASE': 2.379992,
#   'Forecast Bias': 74.34025406837463,
#   'Time Elapsed': 0.19603371620178223}]

# %%
fig = plot_forecast(pred_df, forecast_columns=["naive_predictions"], forecast_display_names=['Naive Predictions'])
fig = format_plot(fig, title=f"Naive: MAE: {metrics['MAE']:.4f} | MSE: {metrics['MSE']:.4f} | MASE: {metrics['MASE']:.4f} | Bias: {metrics['Forecast Bias']:.4f}")
fig.update_xaxes(type="date", range=["2014-01-01", "2014-01-08"])
fig.write_image("imgs/chapter_4/naive.png")
fig.show()

# %% [markdown]
# ----
#
# # Seasonal Naive Forecast

# %%
name = "Seasonal Naive Forecast"
naive_model = NaiveSeasonal(K=48*7)
with LogTime() as timer:
    y_pred, metrics = eval_model(naive_model, ts_train, ts_val, name=name)
metrics['Time Elapsed'] = timer.elapsed
metric_record.append(metrics)
y_pred = format_y_pred(y_pred, "snaive_predictions")
pred_df = pred_df.join(y_pred)
# Out:
# Time Elapsed: 0 microseconds
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\dioni\Documents\GitHub\Modern-Time-Series-Forecasting-with-Python\Notebooks-mios\capitulo4_1.ipynb Celda 17 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X24sZmlsZQ%3D%3D?line=1'>2</a> naive_model = NaiveSeasonal(K=48*7)
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X24sZmlsZQ%3D%3D?line=2'>3</a> with LogTime() as timer:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X24sZmlsZQ%3D%3D?line=3'>4</a>     y_pred, metrics = eval_model(naive_model, ts_train, ts_val, name=name)
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X24sZmlsZQ%3D%3D?line=4'>5</a> metrics['Time Elapsed'] = timer.elapsed
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X24sZmlsZQ%3D%3D?line=5'>6</a> metric_record.append(metrics)
#
# c:\Users\dioni\Documents\GitHub\Modern-Time-Series-Forecasting-with-Python\Notebooks-mios\capitulo4_1.ipynb Celda 17 line 8
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X24sZmlsZQ%3D%3D?line=3'>4</a> model.fit(ts_train)
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X24sZmlsZQ%3D%3D?line=4'>5</a> y_pred = model.predict(len(ts_test))
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X24sZmlsZQ%3D%3D?line=5'>6</a> return y_pred, {
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X24sZmlsZQ%3D%3D?line=6'>7</a>     "Algorithm": name,
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X24sZmlsZQ%3D%3D?line=7'>8</a>     "MAE": mae(actual_series = ts_test, pred_series = y_pred),
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X24sZmlsZQ%3D%3D?line=8'>9</a>     "MSE": mse(actual_series = ts_test, pred_series = y_pred),
#      <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X24sZmlsZQ%3D%3D?line=9'>10</a>     "MASE": mase(actual_series = ts_test, pred_series = y_pred, insample=ts_train),
#      <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X24sZmlsZQ%3D%3D?line=10'>11</a>     "Forecast Bias": forecast_bias(actual_series = ts_test, pred_series = y_pred)
#      <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X24sZmlsZQ%3D%3D?line=11'>12</a> }
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\darts\metrics\metrics.py:87, in multi_ts_support.<locals>.wrapper_multi_ts_support(*args, **kwargs)
#      79 kwargs.pop("pred_series", 0)
#      81 iterator = _build_tqdm_iterator(
#      82     iterable=zip(actual_series, pred_series),
#      83     verbose=verbose,
#      84     total=len(actual_series),
#      85 )
# ---> 87 value_list = _parallel_apply(
#      88     iterator=iterator,
#      89     fn=func,
#      90     n_jobs=n_jobs,
#      91     fn_args=args[num_series_in_args:],
#      92     fn_kwargs=kwargs,
#      93 )
#      95 # in case the reduction is not reducing the metrics sequence to a single value, e.g., if returning the
#      96 # np.ndarray of values with the identity function, we must handle the single TS case, where we should
#      97 # return a single value instead of a np.array of len 1
#      99 if len(value_list) == 1:
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\darts\utils\utils.py:292, in _parallel_apply(iterator, fn, n_jobs, fn_args, fn_kwargs)
#     275 def slice_index(
#     276     index: Union[pd.RangeIndex, pd.DatetimeIndex],
#     277     start: Union[int, pd.Timestamp],
#     278     end: Union[int, pd.Timestamp],
#     279 ) -> Union[pd.RangeIndex, pd.DatetimeIndex]:
#     280     """
#     281     Returns a new Index with the same type as the input `index`, containing the values between `start`
#     282     and `end` included. If start and end are not in the index, the closest values are used instead.
#     283     The start and end values can be either integers (in which case they are interpreted as indices),
#     284     or pd.Timestamps (in which case they are interpreted as actual timestamps).
#     285
#     286
#     287     Parameters
#     288     ----------
#     289     index
#     290         The index to slice.
#     291     start
# --> 292         The start of the returned index.
#     293     end
#     294         The end of the returned index.
#     295
#     296     Returns
#     297     -------
#     298     Union[pd.RangeIndex, pd.DatetimeIndex]
#     299         A new index with the same type as the input `index`, but with only the values between `start` and `end`
#     300         included.
#     301     """
#     303     if type(start) != type(end):
#     304         raise_log(
#     305             ValueError(
#     306                 "start and end values must be of the same type (either both integers or both pd.Timestamps)"
#     307             ),
#     308             logger,
#     309         )
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\joblib\parallel.py:1085, in Parallel.__call__(self, iterable)
#    1076 try:
#    1077     # Only set self._iterating to True if at least a batch
#    1078     # was dispatched. In particular this covers the edge
#    (...)
#    1082     # was very quick and its callback already dispatched all the
#    1083     # remaining jobs.
#    1084     self._iterating = False
# -> 1085     if self.dispatch_one_batch(iterator):
#    1086         self._iterating = self._original_iterator is not None
#    1088     while self.dispatch_one_batch(iterator):
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\joblib\parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\joblib\parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\joblib\_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\joblib\parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\joblib\parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\darts\metrics\metrics.py:134, in multivariate_support.<locals>.wrapper_multivariate_support(*args, **kwargs)
#     130 value_list = []
#     131 for i in range(actual_series.width):
#     132     value_list.append(
#     133         func(
# --> 134             actual_series.univariate_component(i),
#     135             pred_series.univariate_component(i),
#     136             *args[2:],
#     137             **kwargs
#     138         )
#     139     )  # [2:] since we already know the first two arguments are the series
#     140 if "reduction" in kwargs:
#     141     return kwargs["reduction"](value_list)
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\darts\timeseries.py:2991, in TimeSeries.univariate_component(self, index)
#    2971 def univariate_component(self, index: Union[str, int]) -> Self:
#    2972     """
#    2973     Retrieve one of the components of the series
#    2974     and return it as new univariate ``TimeSeries`` instance.
#    (...)
#    2988         A new univariate TimeSeries instance.
#    2989     """
# -> 2991     return self[index if isinstance(index, str) else self.components[index]]
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\darts\timeseries.py:4937, in TimeSeries.__getitem__(self, key)
#    4931     xa_ = self._xa.sel({DIMS[1]: [key]})
#    4932     # selecting components discards the hierarchy, if any
#    4933     xa_ = _xarray_with_attrs(
#    4934         xa_,
#    4935         xa_.attrs[STATIC_COV_TAG].loc[[key]]
#    4936         if adapt_covs_on_component
# -> 4937         else xa_.attrs[STATIC_COV_TAG],
#    4938         None,
#    4939     )
#    4940     return self.__class__(xa_)
#    4941 elif isinstance(key, (int, np.int64)):
#
# KeyError: 'static_covariates'

# %%
fig = plot_forecast(pred_df, forecast_columns=["snaive_predictions"], forecast_display_names=['Seasonal Naive Predictions'])
fig = format_plot(fig, title=f"Seasonal Naive: MAE: {metrics['MAE']:.4f} | MSE: {metrics['MSE']:.4f} | MASE: {metrics['MASE']:.4f} | Bias: {metrics['Forecast Bias']:.4f}")
fig.update_xaxes(type="date", range=["2014-01-01", "2014-01-08"])
fig.write_image("imgs/chapter_4/snaive.png")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'snaive_predictions'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\dioni\Documents\GitHub\Modern-Time-Series-Forecasting-with-Python\Notebooks-mios\capitulo4_1.ipynb Celda 18 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> fig = plot_forecast(pred_df, forecast_columns=["snaive_predictions"], forecast_display_names=['Seasonal Naive Predictions'])
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X25sZmlsZQ%3D%3D?line=1'>2</a> fig = format_plot(fig, title=f"Seasonal Naive: MAE: {metrics['MAE']:.4f} | MSE: {metrics['MSE']:.4f} | MASE: {metrics['MASE']:.4f} | Bias: {metrics['Forecast Bias']:.4f}")
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X25sZmlsZQ%3D%3D?line=2'>3</a> fig.update_xaxes(type="date", range=["2014-01-01", "2014-01-08"])
#
# c:\Users\dioni\Documents\GitHub\Modern-Time-Series-Forecasting-with-Python\Notebooks-mios\capitulo4_1.ipynb Celda 18 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X25sZmlsZQ%3D%3D?line=4'>5</a> else:
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X25sZmlsZQ%3D%3D?line=5'>6</a>     assert len(forecast_columns)==len(forecast_display_names)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X25sZmlsZQ%3D%3D?line=6'>7</a> mask = ~pred_df[forecast_columns[0]].isnull()
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X25sZmlsZQ%3D%3D?line=7'>8</a> # colors = ["rgba("+",".join([str(c) for c in plotting_utils.hex_to_rgb(c)])+",<alpha>)" for c in px.colors.qualitative.Plotly]
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X25sZmlsZQ%3D%3D?line=8'>9</a> colors = [c.replace("rgb", "rgba").replace(")", ", <alpha>)") for c in px.colors.qualitative.Dark2]
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\pandas\core\frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'snaive_predictions'

# %% [markdown]
# # Exponential Smoothing Forecast

# %%
from darts.utils.utils import ModelMode, SeasonalityMode

# %%
name = "Exponential Smoothing"

with warnings.catch_warnings():
    warnings.filterwarnings("ignore",category=FutureWarning)
    ets_model = ExponentialSmoothing(trend=ModelMode.ADDITIVE, damped=True, seasonal=SeasonalityMode.ADDITIVE, seasonal_periods=48*7, random_state=42)
    with LogTime() as timer:
        y_pred, metrics = eval_model(ets_model, ts_train, ts_val, name=name)
    metrics['Time Elapsed'] = timer.elapsed
metric_record.append(metrics)
y_pred = format_y_pred(y_pred,"ets_predictions")
pred_df = pred_df.join(y_pred)
# Out:
# c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\statsmodels\tsa\holtwinters\model.py:917: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
# Time Elapsed: 21 seconds
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\dioni\Documents\GitHub\Modern-Time-Series-Forecasting-with-Python\Notebooks-mios\capitulo4_1.ipynb Celda 21 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X31sZmlsZQ%3D%3D?line=4'>5</a>     ets_model = ExponentialSmoothing(trend=ModelMode.ADDITIVE, damped=True, seasonal=SeasonalityMode.ADDITIVE, seasonal_periods=48*7, random_state=42)
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X31sZmlsZQ%3D%3D?line=5'>6</a>     with LogTime() as timer:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X31sZmlsZQ%3D%3D?line=6'>7</a>         y_pred, metrics = eval_model(ets_model, ts_train, ts_val, name=name)
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X31sZmlsZQ%3D%3D?line=7'>8</a>     metrics['Time Elapsed'] = timer.elapsed
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X31sZmlsZQ%3D%3D?line=8'>9</a> metric_record.append(metrics)
#
# c:\Users\dioni\Documents\GitHub\Modern-Time-Series-Forecasting-with-Python\Notebooks-mios\capitulo4_1.ipynb Celda 21 line 8
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X31sZmlsZQ%3D%3D?line=3'>4</a> model.fit(ts_train)
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X31sZmlsZQ%3D%3D?line=4'>5</a> y_pred = model.predict(len(ts_test))
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X31sZmlsZQ%3D%3D?line=5'>6</a> return y_pred, {
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X31sZmlsZQ%3D%3D?line=6'>7</a>     "Algorithm": name,
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X31sZmlsZQ%3D%3D?line=7'>8</a>     "MAE": mae(actual_series = ts_test, pred_series = y_pred),
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X31sZmlsZQ%3D%3D?line=8'>9</a>     "MSE": mse(actual_series = ts_test, pred_series = y_pred),
#      <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X31sZmlsZQ%3D%3D?line=9'>10</a>     "MASE": mase(actual_series = ts_test, pred_series = y_pred, insample=ts_train),
#      <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X31sZmlsZQ%3D%3D?line=10'>11</a>     "Forecast Bias": forecast_bias(actual_series = ts_test, pred_series = y_pred)
#      <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X31sZmlsZQ%3D%3D?line=11'>12</a> }
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\darts\metrics\metrics.py:87, in multi_ts_support.<locals>.wrapper_multi_ts_support(*args, **kwargs)
#      79 kwargs.pop("pred_series", 0)
#      81 iterator = _build_tqdm_iterator(
#      82     iterable=zip(actual_series, pred_series),
#      83     verbose=verbose,
#      84     total=len(actual_series),
#      85 )
# ---> 87 value_list = _parallel_apply(
#      88     iterator=iterator,
#      89     fn=func,
#      90     n_jobs=n_jobs,
#      91     fn_args=args[num_series_in_args:],
#      92     fn_kwargs=kwargs,
#      93 )
#      95 # in case the reduction is not reducing the metrics sequence to a single value, e.g., if returning the
#      96 # np.ndarray of values with the identity function, we must handle the single TS case, where we should
#      97 # return a single value instead of a np.array of len 1
#      99 if len(value_list) == 1:
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\darts\utils\utils.py:292, in _parallel_apply(iterator, fn, n_jobs, fn_args, fn_kwargs)
#     275 def slice_index(
#     276     index: Union[pd.RangeIndex, pd.DatetimeIndex],
#     277     start: Union[int, pd.Timestamp],
#     278     end: Union[int, pd.Timestamp],
#     279 ) -> Union[pd.RangeIndex, pd.DatetimeIndex]:
#     280     """
#     281     Returns a new Index with the same type as the input `index`, containing the values between `start`
#     282     and `end` included. If start and end are not in the index, the closest values are used instead.
#     283     The start and end values can be either integers (in which case they are interpreted as indices),
#     284     or pd.Timestamps (in which case they are interpreted as actual timestamps).
#     285
#     286
#     287     Parameters
#     288     ----------
#     289     index
#     290         The index to slice.
#     291     start
# --> 292         The start of the returned index.
#     293     end
#     294         The end of the returned index.
#     295
#     296     Returns
#     297     -------
#     298     Union[pd.RangeIndex, pd.DatetimeIndex]
#     299         A new index with the same type as the input `index`, but with only the values between `start` and `end`
#     300         included.
#     301     """
#     303     if type(start) != type(end):
#     304         raise_log(
#     305             ValueError(
#     306                 "start and end values must be of the same type (either both integers or both pd.Timestamps)"
#     307             ),
#     308             logger,
#     309         )
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\joblib\parallel.py:1085, in Parallel.__call__(self, iterable)
#    1076 try:
#    1077     # Only set self._iterating to True if at least a batch
#    1078     # was dispatched. In particular this covers the edge
#    (...)
#    1082     # was very quick and its callback already dispatched all the
#    1083     # remaining jobs.
#    1084     self._iterating = False
# -> 1085     if self.dispatch_one_batch(iterator):
#    1086         self._iterating = self._original_iterator is not None
#    1088     while self.dispatch_one_batch(iterator):
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\joblib\parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\joblib\parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\joblib\_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\joblib\parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\joblib\parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\darts\metrics\metrics.py:134, in multivariate_support.<locals>.wrapper_multivariate_support(*args, **kwargs)
#     130 value_list = []
#     131 for i in range(actual_series.width):
#     132     value_list.append(
#     133         func(
# --> 134             actual_series.univariate_component(i),
#     135             pred_series.univariate_component(i),
#     136             *args[2:],
#     137             **kwargs
#     138         )
#     139     )  # [2:] since we already know the first two arguments are the series
#     140 if "reduction" in kwargs:
#     141     return kwargs["reduction"](value_list)
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\darts\timeseries.py:2991, in TimeSeries.univariate_component(self, index)
#    2971 def univariate_component(self, index: Union[str, int]) -> Self:
#    2972     """
#    2973     Retrieve one of the components of the series
#    2974     and return it as new univariate ``TimeSeries`` instance.
#    (...)
#    2988         A new univariate TimeSeries instance.
#    2989     """
# -> 2991     return self[index if isinstance(index, str) else self.components[index]]
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\darts\timeseries.py:4937, in TimeSeries.__getitem__(self, key)
#    4931     xa_ = self._xa.sel({DIMS[1]: [key]})
#    4932     # selecting components discards the hierarchy, if any
#    4933     xa_ = _xarray_with_attrs(
#    4934         xa_,
#    4935         xa_.attrs[STATIC_COV_TAG].loc[[key]]
#    4936         if adapt_covs_on_component
# -> 4937         else xa_.attrs[STATIC_COV_TAG],
#    4938         None,
#    4939     )
#    4940     return self.__class__(xa_)
#    4941 elif isinstance(key, (int, np.int64)):
#
# KeyError: 'static_covariates'

# %% [markdown]
# # Arima

# %%
name = "ARIMA"
#Not using AutoARIMA because it just takes too much time for long time series
# arima_model = AutoARIMA(max_p=5, max_q=3, m=48, seasonal=False)
arima_model = ARIMA(p=2, d=1, q=1, seasonal_order=(1, 1, 1, 48))
# Taking only latest 8000 points for training (Time constraints)
# Reduce 8000 if it is taking too much time or consuming all the memory
with LogTime() as timer:
    y_pred, metrics = eval_model(arima_model, ts_train[-8000:], ts_val,  name=name)
metrics['Time Elapsed'] = timer.elapsed
metric_record.append(metrics)
y_pred = format_y_pred(y_pred, "arima_predictions")
pred_df = pred_df.join(y_pred)
# Out:
# Time Elapsed: 6 minutes and 19 seconds
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\dioni\Documents\GitHub\Modern-Time-Series-Forecasting-with-Python\Notebooks-mios\capitulo4_1.ipynb Celda 23 line 8
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X35sZmlsZQ%3D%3D?line=4'>5</a> # Taking only latest 8000 points for training (Time constraints)
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X35sZmlsZQ%3D%3D?line=5'>6</a> # Reduce 8000 if it is taking too much time or consuming all the memory
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X35sZmlsZQ%3D%3D?line=6'>7</a> with LogTime() as timer:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X35sZmlsZQ%3D%3D?line=7'>8</a>     y_pred, metrics = eval_model(arima_model, ts_train[-8000:], ts_val,  name=name)
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X35sZmlsZQ%3D%3D?line=8'>9</a> metrics['Time Elapsed'] = timer.elapsed
#      <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X35sZmlsZQ%3D%3D?line=9'>10</a> metric_record.append(metrics)
#
# c:\Users\dioni\Documents\GitHub\Modern-Time-Series-Forecasting-with-Python\Notebooks-mios\capitulo4_1.ipynb Celda 23 line 8
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X35sZmlsZQ%3D%3D?line=3'>4</a> model.fit(ts_train)
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X35sZmlsZQ%3D%3D?line=4'>5</a> y_pred = model.predict(len(ts_test))
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X35sZmlsZQ%3D%3D?line=5'>6</a> return y_pred, {
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X35sZmlsZQ%3D%3D?line=6'>7</a>     "Algorithm": name,
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X35sZmlsZQ%3D%3D?line=7'>8</a>     "MAE": mae(actual_series = ts_test, pred_series = y_pred),
#       <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X35sZmlsZQ%3D%3D?line=8'>9</a>     "MSE": mse(actual_series = ts_test, pred_series = y_pred),
#      <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X35sZmlsZQ%3D%3D?line=9'>10</a>     "MASE": mase(actual_series = ts_test, pred_series = y_pred, insample=ts_train),
#      <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X35sZmlsZQ%3D%3D?line=10'>11</a>     "Forecast Bias": forecast_bias(actual_series = ts_test, pred_series = y_pred)
#      <a href='vscode-notebook-cell:/c%3A/Users/dioni/Documents/GitHub/Modern-Time-Series-Forecasting-with-Python/Notebooks-mios/capitulo4_1.ipynb#X35sZmlsZQ%3D%3D?line=11'>12</a> }
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\darts\metrics\metrics.py:87, in multi_ts_support.<locals>.wrapper_multi_ts_support(*args, **kwargs)
#      79 kwargs.pop("pred_series", 0)
#      81 iterator = _build_tqdm_iterator(
#      82     iterable=zip(actual_series, pred_series),
#      83     verbose=verbose,
#      84     total=len(actual_series),
#      85 )
# ---> 87 value_list = _parallel_apply(
#      88     iterator=iterator,
#      89     fn=func,
#      90     n_jobs=n_jobs,
#      91     fn_args=args[num_series_in_args:],
#      92     fn_kwargs=kwargs,
#      93 )
#      95 # in case the reduction is not reducing the metrics sequence to a single value, e.g., if returning the
#      96 # np.ndarray of values with the identity function, we must handle the single TS case, where we should
#      97 # return a single value instead of a np.array of len 1
#      99 if len(value_list) == 1:
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\darts\utils\utils.py:292, in _parallel_apply(iterator, fn, n_jobs, fn_args, fn_kwargs)
#     275 def slice_index(
#     276     index: Union[pd.RangeIndex, pd.DatetimeIndex],
#     277     start: Union[int, pd.Timestamp],
#     278     end: Union[int, pd.Timestamp],
#     279 ) -> Union[pd.RangeIndex, pd.DatetimeIndex]:
#     280     """
#     281     Returns a new Index with the same type as the input `index`, containing the values between `start`
#     282     and `end` included. If start and end are not in the index, the closest values are used instead.
#     283     The start and end values can be either integers (in which case they are interpreted as indices),
#     284     or pd.Timestamps (in which case they are interpreted as actual timestamps).
#     285
#     286
#     287     Parameters
#     288     ----------
#     289     index
#     290         The index to slice.
#     291     start
# --> 292         The start of the returned index.
#     293     end
#     294         The end of the returned index.
#     295
#     296     Returns
#     297     -------
#     298     Union[pd.RangeIndex, pd.DatetimeIndex]
#     299         A new index with the same type as the input `index`, but with only the values between `start` and `end`
#     300         included.
#     301     """
#     303     if type(start) != type(end):
#     304         raise_log(
#     305             ValueError(
#     306                 "start and end values must be of the same type (either both integers or both pd.Timestamps)"
#     307             ),
#     308             logger,
#     309         )
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\joblib\parallel.py:1085, in Parallel.__call__(self, iterable)
#    1076 try:
#    1077     # Only set self._iterating to True if at least a batch
#    1078     # was dispatched. In particular this covers the edge
#    (...)
#    1082     # was very quick and its callback already dispatched all the
#    1083     # remaining jobs.
#    1084     self._iterating = False
# -> 1085     if self.dispatch_one_batch(iterator):
#    1086         self._iterating = self._original_iterator is not None
#    1088     while self.dispatch_one_batch(iterator):
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\joblib\parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\joblib\parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\joblib\_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\joblib\parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\joblib\parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\darts\metrics\metrics.py:134, in multivariate_support.<locals>.wrapper_multivariate_support(*args, **kwargs)
#     130 value_list = []
#     131 for i in range(actual_series.width):
#     132     value_list.append(
#     133         func(
# --> 134             actual_series.univariate_component(i),
#     135             pred_series.univariate_component(i),
#     136             *args[2:],
#     137             **kwargs
#     138         )
#     139     )  # [2:] since we already know the first two arguments are the series
#     140 if "reduction" in kwargs:
#     141     return kwargs["reduction"](value_list)
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\darts\timeseries.py:2991, in TimeSeries.univariate_component(self, index)
#    2971 def univariate_component(self, index: Union[str, int]) -> Self:
#    2972     """
#    2973     Retrieve one of the components of the series
#    2974     and return it as new univariate ``TimeSeries`` instance.
#    (...)
#    2988         A new univariate TimeSeries instance.
#    2989     """
# -> 2991     return self[index if isinstance(index, str) else self.components[index]]
#
# File c:\Users\dioni\anaconda3\envs\modern-ts\lib\site-packages\darts\timeseries.py:4937, in TimeSeries.__getitem__(self, key)
#    4931     xa_ = self._xa.sel({DIMS[1]: [key]})
#    4932     # selecting components discards the hierarchy, if any
#    4933     xa_ = _xarray_with_attrs(
#    4934         xa_,
#    4935         xa_.attrs[STATIC_COV_TAG].loc[[key]]
#    4936         if adapt_covs_on_component
# -> 4937         else xa_.attrs[STATIC_COV_TAG],
#    4938         None,
#    4939     )
#    4940     return self.__class__(xa_)
#    4941 elif isinstance(key, (int, np.int64)):
#
# KeyError: 'static_covariates'

# %%
fig = plot_forecast(pred_df, forecast_columns=["arima_predictions"], forecast_display_names=['ARIMA Predictions'])
fig = format_plot(fig, title=f"ARIMA: MAE: {metrics['MAE']:.4f} | MSE: {metrics['MSE']:.4f} | MASE: {metrics['MASE']:.4f} | Bias: {metrics['Forecast Bias']:.4f}")
fig.update_xaxes(type="date", range=["2014-01-01", "2014-01-08"])
fig.write_image("imgs/chapter_4/arima.png")
fig.show()
